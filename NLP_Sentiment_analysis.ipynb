# %%
import spacy

# %%
nlp=spacy.load('en_core_web_lg')

# %%
#it will give you the vector for the sentence
nlp(u'lion').vector
# Out:
# array([ 1.8963e-01, -4.0309e-01,  3.5350e-01, -4.7907e-01, -4.3311e-01,
#         2.3857e-01,  2.6962e-01,  6.4332e-02,  3.0767e-01,  1.3712e+00,
#        -3.7582e-01, -2.2713e-01, -3.5657e-01, -2.5355e-01,  1.7543e-02,
#         3.3962e-01,  7.4723e-02,  5.1226e-01, -3.9759e-01,  5.1333e-03,
#        -3.0929e-01,  4.8911e-02, -1.8610e-01, -4.1702e-01, -8.1639e-01,
#        -1.6908e-01, -2.6246e-01, -1.5983e-02,  1.2479e-01, -3.7276e-02,
#        -5.7125e-01, -1.6296e-01,  1.2376e-01, -5.5464e-02,  1.3244e-01,
#         2.7519e-02,  1.2592e-01, -3.2722e-01, -4.9165e-01, -3.5559e-01,
#        -3.0630e-01,  6.1185e-02, -1.6932e-01, -6.2405e-02,  6.5763e-01,
#        -2.7925e-01, -3.0450e-03, -2.2400e-02, -2.8015e-01, -2.1975e-01,
#        -4.3188e-01,  3.9864e-02, -2.2102e-01, -4.2693e-02,  5.2748e-02,
#         2.8726e-01,  1.2315e-01, -2.8662e-02,  7.8294e-02,  4.6754e-01,
#        -2.4589e-01, -1.1064e-01,  7.2250e-02, -9.4980e-02, -2.7548e-01,
# ...

# %%
nlp(u'my name is umair ansari.').vector
# Out:
# array([ 6.41850010e-02,  1.74697995e-01, -1.10399626e-01, -1.38580158e-01,
#         2.35956669e-01,  8.67966637e-02,  6.97816685e-02, -3.73813301e-01,
#        -1.85792163e-01,  1.25048339e+00, -1.85720786e-01,  4.91953306e-02,
#        -2.88341641e-02,  4.79246676e-02, -2.35698316e-02,  8.53634998e-02,
#         1.08540021e-02,  5.46768367e-01, -1.61191165e-01,  9.54633281e-02,
#        -5.14736660e-02,  1.13424681e-01, -4.05076705e-02,  2.98507158e-02,
#         2.14803338e-01, -4.87998128e-04, -1.53204501e-01,  5.98094948e-02,
#         4.77625020e-02,  2.12110996e-01,  3.47513258e-02,  3.72011550e-02,
#        -2.34268364e-02,  7.71873370e-02, -1.55883327e-01,  1.13944961e-02,
#        -2.00832891e-03, -8.28083325e-03, -8.14822316e-02, -2.39053313e-02,
#        -7.62616517e-03,  4.18002196e-02,  1.52721658e-01, -1.05343997e-01,
#         3.30509990e-02, -3.09918299e-02, -1.77893996e-01, -1.14361010e-01,
# ...

# %%
#to check relationship between vectors

tokens=nlp(u'lion cat pet')

# %%
#we will get similarity value between o and 1
#rating 0 for least similar and 1 to all similar 
for token in tokens:
    for token2 in tokens:

        print(token.text,token2.text,token.similarity(token2))
# Out:
# lion lion 1.0
# lion cat 0.52654374
# lion pet 0.39923766
# cat lion 0.52654374
# cat cat 1.0
# cat pet 0.7505456
# pet lion 0.39923766
# pet cat 0.7505456
# pet pet 1.0

# %%
#similarity if words
tokenss=nlp(u'live love hate sex')
for tokens in tokenss:
    for tokenn in tokenss:
        print(tokenn.text,tokens.text,tokenn.similarity(tokens))
# Out:
# live live 1.0
# love live 0.48390356
# hate live 0.3669464
# sex live 0.3501613
# live love 0.48390356
# love love 1.0
# hate love 0.6393099
# sex love 0.3866422
# live hate 0.3669464
# love hate 0.6393099
# hate hate 1.0
# sex hate 0.3019451
# live sex 0.3501613
# love sex 0.3866422
# hate sex 0.3019451
# sex sex 1.0

# %%
 token=nlp(u"dog cat nargle")

# %%
#contains the length of vector in the nlp vocab on which we can work on
nlp.vocab.length,nlp.vocab.vectors.n_keys,nlp.vocab.vectors.shape
# Out:
# (1340243, 684830, (684831, 300))

# %%
a=nlp(u'owl')

# %%
a.text,a.has_vector,a.vector_norm
# Out:
# ('owl', True, 6.6680066169580305)

# %%
#oov stands for out oy vocabulary
#sum of squares of the dimension
for token in token:
    print(token.text,token.has_vector,token.vector_norm,token.is_oov)
# Out:
# dog True 7.0336733 False
# cat True 6.6808186 False
# nargle False 0.0 True

# %%
from scipy import spatial

# %%
cosine_similarity=lambda vec1,vec2:1-spatial.distance.cosine(vec1,vec2)

# %%
king=nlp.vocab['king'].vector
man=nlp.vocab['man'].vector
woman=nlp.vocab['woman'].vector

# %%
new_vec=king-man+woman

# %%
computed_similarity=[]
for word in nlp.vocab:
    if word.has_vector:
        if word.is_lower:
            if word.is_alpha:
                similarity=cosine_similarity(new_vec,word.vector)
                computed_similarity.append((word,similarity))

# %%
computed_similarity=sorted(computed_similarity,key=lambda item:-item[1])

# %%
type(computed_similarity)
# Out:
# list

# %%
for words in computed_similarity[:10]:
    print(words[0].text)
# Out:
# king
# queen
# prince
# kings
# princess
# royal
# throne
# queens
# monarch
# kingdom
